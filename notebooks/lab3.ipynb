# %%
# !pip install owlready2
# Out:
# Requirement already satisfied: owlready2 in c:\users\rache\anaconda3\lib\site-packages (0.50)

# %%
from owlready2 import *
from pathlib import Path

cc_onto = get_ontology("http://climate-change.org/kg/swrl#")

with cc_onto:
    class Organization(Thing): pass
    class GeopoliticalEntity(Thing): pass
    class Agreement(Thing): pass
    class PolicyLinkedOrg(Organization): pass
    class locatedIn(Organization >> GeopoliticalEntity): pass
    class signedBy(Agreement >> GeopoliticalEntity): pass

family_path = Path("../kg_artifacts/family.owl")

base = "http://www.owl-ontologies.com/unnamed.owl#"
age_prop = base + "age"

onto = get_ontology("http://www.owl-ontologies.com/unnamed.owl")
with open(family_path, "rb") as f:
    onto.graph.parse(f)

print("Ontology loaded.")

# Read individuals and ages from the RDF triple store
individuals = {}
age_storid = onto.graph._abbreviate(age_prop, create_if_missing=False)

for s, p, o, d in onto.graph.execute(
    "SELECT s, p, o, d FROM quads WHERE p=?", [age_storid]
):
    name = onto.graph._unabbreviate(s).replace(base, "")
    individuals[name] = int(o)

print(f"Individuals found: {len(individuals)}")
print()
print("SWRL rule:") #si une personne a un âge supérieur à 60, alors c’est une OldPerson
print("  Person(?p), age(?p, ?a), swrlb:greaterThan(?a, 60) -> OldPerson(?p)")
print()
print("Individuals evaluated:")

inferred = []
for name, age_val in sorted(individuals.items()):
    is_old = age_val > 60
    if is_old:
        inferred.append((name, age_val))
    flag = " --> inferred as OldPerson" if is_old else ""
    print(f"  {name} (age: {age_val}){flag}")

print()
print("OldPerson instances inferred (age > 60):")
for name, age_val in inferred:
    print(f"  {name} (age: {age_val})")
# Out:
# Ontology loaded.
# Individuals found: 12
#
# SWRL rule:
#   Person(?p), age(?p, ?a), swrlb:greaterThan(?a, 60) -> OldPerson(?p)
#
# Individuals evaluated:
#   Alex (age: 25)
#   Chloé (age: 18)
#   Claude (age: 5)
#   John (age: 45)
#   Marie (age: 69) --> inferred as OldPerson
#   Michael (age: 5)
#   Paul (age: 38)
#   Pedro (age: 10)
#   Peter (age: 70) --> inferred as OldPerson
#   Sylvie (age: 30)
#   Thomas (age: 40)
#   Tom (age: 10)
#
# OldPerson instances inferred (age > 60):
#   Marie (age: 69)
#   Peter (age: 70)

# %%
# SWRL rule on the Climate Change KB (simulated reasoning)
# Rule: Organization(?o), locatedIn(?o, ?g), signedBy(?a, ?g) -> PolicyLinkedOrg(?o)
# an organization located in a country that signed a climate agreement is inferred as a PolicyLinkedOrg

print("SWRL rule:")
print("  Organization(?o), locatedIn(?o, ?g), signedBy(?a, ?g) -> PolicyLinkedOrg(?o)")
print()

# Knowledge base
organizations = {
    "IPCC": "Switzerland",
    "UnitedNations": "UnitedStates",
    "NASA": "UnitedStates",
    "NOAA": "UnitedStates",
    "FEMA": "UnitedStates",
}

signatories = {
    "ParisAgreement": ["France", "UnitedStates", "UnitedKingdom", "Switzerland",
                       "Germany", "China", "India", "Brazil", "Canada", "Australia"],
    "KyotoProtocol":  ["France", "UnitedKingdom", "Germany", "China",
                       "India", "Canada", "Japan", "Russia"],
}

# Apply rule
policy_linked = []
for org, country in organizations.items():
    for agreement, countries in signatories.items():
        if country in countries:
            policy_linked.append((org, country, agreement))
            break

print("Reasoning result:")
print(f"  {'Organization':<20} {'LocatedIn':<20} {'Agreement':<20} {'Inferred'}")
print("  " + "-" * 75)
for org, country in organizations.items():
    inferred = any(p[0] == org for p in policy_linked)
    agreement = next((p[2] for p in policy_linked if p[0] == org), "none")
    print(f"  {org:<20} {country:<20} {agreement:<20} {'PolicyLinkedOrg' if inferred else ''}")

print()
print("PolicyLinkedOrg instances inferred:")
for org, country, agreement in policy_linked:
    print(f"  {org} (via {agreement}, located in {country})")

cc_onto.save(file=r"climate_swrl.owl", format="rdfxml")
print("climate_swrl.owl saved.")
# Out:
# SWRL rule:
#   Organization(?o), locatedIn(?o, ?g), signedBy(?a, ?g) -> PolicyLinkedOrg(?o)
#
# Reasoning result:
#   Organization         LocatedIn            Agreement            Inferred
#   ---------------------------------------------------------------------------
#   IPCC                 Switzerland          ParisAgreement       PolicyLinkedOrg
#   UnitedNations        UnitedStates         ParisAgreement       PolicyLinkedOrg
#   NASA                 UnitedStates         ParisAgreement       PolicyLinkedOrg
#   NOAA                 UnitedStates         ParisAgreement       PolicyLinkedOrg
#   FEMA                 UnitedStates         ParisAgreement       PolicyLinkedOrg
#
# PolicyLinkedOrg instances inferred:
#   IPCC (via ParisAgreement, located in Switzerland)
#   UnitedNations (via ParisAgreement, located in UnitedStates)
#   NASA (via ParisAgreement, located in UnitedStates)
#   NOAA (via ParisAgreement, located in UnitedStates)
#   FEMA (via ParisAgreement, located in UnitedStates)
# climate_swrl.owl saved.

# %% [markdown]
# ### knowledge graph embeddings

# %%
# !pip install pykeen
# Out:
# Requirement already satisfied: pykeen in c:\users\rache\anaconda3\lib\site-packages (1.11.1)
# Requirement already satisfied: dataclasses-json in c:\users\rache\anaconda3\lib\site-packages (from pykeen) (0.6.7)
# Requirement already satisfied: numpy in c:\users\rache\anaconda3\lib\site-packages (from pykeen) (1.26.4)
# Requirement already satisfied: scipy>=1.7.0 in c:\users\rache\anaconda3\lib\site-packages (from pykeen) (1.13.1)
# Requirement already satisfied: click in c:\users\rache\anaconda3\lib\site-packages (from pykeen) (8.3.1)
# Requirement already satisfied: click_default_group in c:\users\rache\anaconda3\lib\site-packages (from pykeen) (1.2.4)
# Requirement already satisfied: scikit-learn in c:\users\rache\anaconda3\lib\site-packages (from pykeen) (1.4.2)
# Requirement already satisfied: torch>=2.0 in c:\users\rache\anaconda3\lib\site-packages (from pykeen) (2.10.0)
# Requirement already satisfied: tqdm in c:\users\rache\anaconda3\lib\site-packages (from pykeen) (4.66.4)
# Requirement already satisfied: requests in c:\users\rache\anaconda3\lib\site-packages (from pykeen) (2.32.2)
# Requirement already satisfied: optuna>=2.0.0 in c:\users\rache\anaconda3\lib\site-packages (from pykeen) (4.8.0)
# Requirement already satisfied: pandas>=1.0.0 in c:\users\rache\anaconda3\lib\site-packages (from pykeen) (2.2.2)
# Requirement already satisfied: tabulate in c:\users\rache\anaconda3\lib\site-packages (from pykeen) (0.9.0)
# Requirement already satisfied: more_click in c:\users\rache\anaconda3\lib\site-packages (from pykeen) (0.1.3)
# Requirement already satisfied: more_itertools in c:\users\rache\anaconda3\lib\site-packages (from pykeen) (10.1.0)
# Requirement already satisfied: pystow>=0.4.3 in c:\users\rache\anaconda3\lib\site-packages (from pykeen) (0.8.3)
# Requirement already satisfied: docdata>=0.0.5 in c:\users\rache\anaconda3\lib\site-packages (from pykeen) (0.0.5)
# Requirement already satisfied: class_resolver>=0.6.0 in c:\users\rache\anaconda3\lib\site-packages (from pykeen) (0.7.1)
# Requirement already satisfied: pyyaml in c:\users\rache\anaconda3\lib\site-packages (from pykeen) (6.0.1)
# Requirement already satisfied: torch_max_mem>=0.1.4 in c:\users\rache\anaconda3\lib\site-packages (from pykeen) (0.1.4)
# Requirement already satisfied: torch-ppr>=0.0.7 in c:\users\rache\anaconda3\lib\site-packages (from pykeen) (0.0.8)
# Requirement already satisfied: typing_extensions in c:\users\rache\anaconda3\lib\site-packages (from pykeen) (4.15.0)
# Requirement already satisfied: alembic>=1.5.0 in c:\users\rache\anaconda3\lib\site-packages (from optuna>=2.0.0->pykeen) (1.18.4)
# Requirement already satisfied: colorlog in c:\users\rache\anaconda3\lib\site-packages (from optuna>=2.0.0->pykeen) (6.10.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\rache\anaconda3\lib\site-packages (from optuna>=2.0.0->pykeen) (23.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in c:\users\rache\anaconda3\lib\site-packages (from optuna>=2.0.0->pykeen) (2.0.30)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\rache\anaconda3\lib\site-packages (from pandas>=1.0.0->pykeen) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rache\anaconda3\lib\site-packages (from pandas>=1.0.0->pykeen) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\rache\anaconda3\lib\site-packages (from pandas>=1.0.0->pykeen) (2023.3)
# Requirement already satisfied: filelock in c:\users\rache\anaconda3\lib\site-packages (from torch>=2.0->pykeen) (3.13.1)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\rache\anaconda3\lib\site-packages (from torch>=2.0->pykeen) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\rache\anaconda3\lib\site-packages (from torch>=2.0->pykeen) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\rache\anaconda3\lib\site-packages (from torch>=2.0->pykeen) (3.1.4)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\rache\anaconda3\lib\site-packages (from torch>=2.0->pykeen) (2024.3.1)
# Requirement already satisfied: setuptools in c:\users\rache\anaconda3\lib\site-packages (from torch>=2.0->pykeen) (69.5.1)
# Requirement already satisfied: colorama in c:\users\rache\anaconda3\lib\site-packages (from click->pykeen) (0.4.6)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\rache\anaconda3\lib\site-packages (from dataclasses-json->pykeen) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\rache\anaconda3\lib\site-packages (from dataclasses-json->pykeen) (0.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\rache\anaconda3\lib\site-packages (from requests->pykeen) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rache\anaconda3\lib\site-packages (from requests->pykeen) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\rache\anaconda3\lib\site-packages (from requests->pykeen) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rache\anaconda3\lib\site-packages (from requests->pykeen) (2025.10.5)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\rache\anaconda3\lib\site-packages (from scikit-learn->pykeen) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\rache\anaconda3\lib\site-packages (from scikit-learn->pykeen) (2.2.0)
# Requirement already satisfied: Mako in c:\users\rache\anaconda3\lib\site-packages (from alembic>=1.5.0->optuna>=2.0.0->pykeen) (1.3.10)
# Requirement already satisfied: six>=1.5 in c:\users\rache\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.0.0->pykeen) (1.16.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\rache\anaconda3\lib\site-packages (from sqlalchemy>=1.4.2->optuna>=2.0.0->pykeen) (3.0.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\rache\anaconda3\lib\site-packages (from sympy>=1.13.3->torch>=2.0->pykeen) (1.3.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\rache\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json->pykeen) (1.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\rache\anaconda3\lib\site-packages (from jinja2->torch>=2.0->pykeen) (2.1.3)

# %%
# prepare KGE data and split into train/valid/test
import pandas as pd
import numpy as np
from pathlib import Path
from rdflib import Graph, URIRef, Literal

expanded_path = Path(r"expanded_kb.nt")

print("Loading expanded KB...")
g = Graph()
g.parse(str(expanded_path), format="nt")
print(f"Total triples loaded: {len(g)}")

# Keep only URI-URI-URI triples (no literals) for KGE
triples = []
for s, p, o in g:
    if isinstance(s, URIRef) and isinstance(p, URIRef) and isinstance(o, URIRef):
        triples.append((str(s), str(p), str(o)))

print(f"URI-only triples (usable for KGE): {len(triples)}")

# Shuffle and split 80/10/10
np.random.seed(42)
np.random.shuffle(triples)

n = len(triples)
n_train = int(0.8 * n)
n_valid = int(0.1 * n)

train = triples[:n_train]
valid = triples[n_train:n_train + n_valid]
test  = triples[n_train + n_valid:]

print(f"\nSplit:")
print(f"  Train: {len(train)}")
print(f"  Valid: {len(valid)}")
print(f"  Test:  {len(test)}")

# Save as tab-separated txt files
out_dir = Path(r".")

for split_name, split_data in [("train", train), ("valid", valid), ("test", test)]:
    path = out_dir / f"{split_name}.txt"
    with open(path, "w", encoding="utf-8") as f:
        for s, p, o in split_data:
            f.write(f"{s}\t{p}\t{o}\n")
    print(f"  {split_name}.txt saved: {path}")
# Out:
# Loading expanded KB...
# Total triples loaded: 72798
# URI-only triples (usable for KGE): 54370
#
# Split:
#   Train: 43496
#   Valid: 5437
#   Test:  5437
#   train.txt saved: train.txt
#   valid.txt saved: valid.txt
#   test.txt saved: test.txt

# %%
from pykeen.pipeline import pipeline
from pykeen.triples import TriplesFactory

out_dir = Path(r".")

# Load splits
tf_train = TriplesFactory.from_path(out_dir / "train.txt")
tf_valid = TriplesFactory.from_path(
    out_dir / "valid.txt",
    entity_to_id=tf_train.entity_to_id,
    relation_to_id=tf_train.relation_to_id,
)
tf_test = TriplesFactory.from_path(
    out_dir / "test.txt",
    entity_to_id=tf_train.entity_to_id,
    relation_to_id=tf_train.relation_to_id,
)

print(f"Entities: {tf_train.num_entities}")
print(f"Relations: {tf_train.num_relations}")
print(f"Train: {tf_train.num_triples}")
print(f"Valid: {tf_valid.num_triples}")
print(f"Test: {tf_test.num_triples}")

print("\nTraining TransE...")
result_transe = pipeline(
    training=tf_train,
    validation=tf_valid,
    testing=tf_test,
    model="TransE",
    model_kwargs=dict(embedding_dim=100),
    optimizer="Adam",
    optimizer_kwargs=dict(lr=0.001),
    training_kwargs=dict(num_epochs=100, batch_size=512),
    negative_sampler="basic",
    evaluator_kwargs=dict(filtered=True),
    random_seed=42,
)

print("\nTransE results:")
metrics_transe = result_transe.metric_results.to_dict()
for metric in ["hits_at_1", "hits_at_3", "hits_at_10", "inverse_harmonic_mean_rank"]:
    val = metrics_transe.get("both.realistic." + metric, "N/A")
    label = "MRR" if metric == "inverse_harmonic_mean_rank" else metric
    print(f"  {label}: {val:.4f}" if isinstance(val, float) else f"  {label}: {val}")
# Out:
# You're trying to map triples with 4519 entities and 80 relations that are not in the training set. These triples will be excluded from the mapping.
# In total 4521 from 5437 triples were filtered out
# You're trying to map triples with 4527 entities and 102 relations that are not in the training set. These triples will be excluded from the mapping.
# In total 4532 from 5437 triples were filtered out
# No cuda devices were available. The model runs on CPU
# Entities: 38265
# Relations: 2563
# Train: 43496
# Valid: 916
# Test: 905
#
# Training TransE...
# C:\Users\rache\anaconda3\Lib\site-packages\torch\utils\data\dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# Training epochs on cpu:   0%|          | 0/100 [00:00<?, ?epoch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# WARNING:pykeen.utils:Using automatic batch size on device.type='cpu' can cause unexplained out-of-memory crashes. Therefore, we use a conservative small batch_size=32. Performance may be improved by explicitly specifying a larger batch size.
# Evaluating on cpu:   0%|          | 0.00/905 [00:00<?, ?triple/s]
# WARNING:torch_max_mem.api:Encountered tensors on device_types={'cpu'} while only ['cuda'] are considered safe for automatic memory utilization maximization. This may lead to undocumented crashes (but can be safe, too).
# INFO:pykeen.evaluation.evaluator:Evaluation took 13.23s seconds
# TransE results:
#   hits_at_1: N/A
#   hits_at_3: N/A
#   hits_at_10: N/A
#   MRR: N/A

# %%
metrics = result_transe.metric_results.to_dict()
for k, v in list(metrics.items())[:30]:
    print(k, "->", v)
# Out:
# head -> {'optimistic': {'inverse_geometric_mean_rank': 0.008273223941934466, 'adjusted_geometric_mean_rank_index': 0.9914873739382015, 'variance': 30092911.28762858, 'count': 905.0, 'standard_deviation': 5485.7006195771, 'z_geometric_mean_rank': 29.874753349318368, 'geometric_mean_rank': 120.87186410261457, 'z_arithmetic_mean_rank': 45.864999172029506, 'arithmetic_mean_rank': 2291.2872928176794, 'adjusted_arithmetic_mean_rank_index': 0.8802537496710561, 'inverse_harmonic_mean_rank': 0.10501113920823682, 'adjusted_inverse_harmonic_mean_rank': 0.10475068028498714, 'z_inverse_harmonic_mean_rank': 480.89080289005994, 'median_absolute_deviation': 161.6036418171106, 'median_rank': 111.0, 'inverse_median_rank': 0.009009009009009009, 'adjusted_arithmetic_mean_rank': 0.11979227144399597, 'harmonic_mean_rank': 9.522799271961068, 'inverse_arithmetic_mean_rank': 0.00043643588612157997, 'hits_at_1': 0.019889502762430938, 'hits_at_3': 0.14696132596685083, 'hits_at_5': 0.19337016574585636, 'hits_at_10': 0.25303867403314917, 'z_hits_at_k': 470.3852551231027, 'adjusted_hits_at_k': 0.25284335597914476}, 'realistic': {'inverse_geometric_mean_rank': 0.00827321968972683, 'adjusted_geometric_mean_rank_index': 0.9914873690466754, 'variance': 30092910.0, 'count': 905.0, 'standard_deviation': 5485.70068359375, 'z_geometric_mean_rank': 29.874753201930574, 'geometric_mean_rank': 120.87193298339844, 'z_arithmetic_mean_rank': 45.864997676478076, 'arithmetic_mean_rank': 2291.287841796875, 'adjusted_arithmetic_mean_rank_index': 0.8802537209680195, 'inverse_harmonic_mean_rank': 0.10501113533973694, 'adjusted_inverse_harmonic_mean_rank': 0.10475067641536145, 'z_inverse_harmonic_mean_rank': 480.8907851253314, 'median_absolute_deviation': 161.6036418171106, 'median_rank': 111.0, 'inverse_median_rank': 0.009009009227156639, 'adjusted_arithmetic_mean_rank': 0.11979230014553201, 'harmonic_mean_rank': 9.522799622770988, 'inverse_arithmetic_mean_rank': 0.00043643577373586595, 'hits_at_1': 0.019889502762430938, 'hits_at_3': 0.14696132596685083, 'hits_at_5': 0.19337016574585636, 'hits_at_10': 0.25303867403314917, 'z_hits_at_k': 470.3852551231027, 'adjusted_hits_at_k': 0.25284335597914476}, 'pessimistic': {'inverse_geometric_mean_rank': 0.00827321763515227, 'adjusted_geometric_mean_rank_index': 
'harmonic_mean_rank': 9.320923466228303, 'inverse_arithmetic_mean_rank': 0.00036650814581662416, 'hits_at_1': 0.022651933701657457, 'hits_at_3': 0.143646408839779, 'hits_at_5': 0.19116022099447513, 'hits_at_10': 0.2613259668508287, 'z_hits_at_k': 687.0306880977826, 'adjusted_hits_at_k': 0.26113281359609586}, 'pessimistic': {'inverse_geometric_mean_rank': 0.007527299166663373, 'adjusted_geometric_mean_rank_index': 0.9906340839094666, 'variance': 37737195.42574677, 'count': 1810.0, 'standard_deviation': 6143.060753870725, 'z_geometric_mean_rank': 42.19561524662708, 'geometric_mean_rank': 132.84977491379158, 'z_arithmetic_mean_rank': 63.17853267226023, 'arithmetic_mean_rank': 2728.453591160221, 'adjusted_arithmetic_mean_rank_index': 0.8573951620569856, 'inverse_harmonic_mean_rank': 0.10728550770993181, 'adjusted_inverse_harmonic_mean_rank': 0.10702570798915191, 'z_inverse_harmonic_mean_rank': 694.8487275973953, 'median_absolute_deviation': 166.0514484726274, 'median_rank': 114.0, 'inverse_median_rank': 0.008771929824561403, 'adjusted_arithmetic_mean_rank': 0.14264966448233782, 'harmonic_mean_rank': 9.320923406576995, 'inverse_arithmetic_mean_rank': 0.00036650797478830115, 'hits_at_1': 0.022651933701657457, 'hits_at_3': 0.143646408839779, 'hits_at_5': 0.19116022099447513, 'hits_at_10': 0.2613259668508287, 'z_hits_at_k': 687.0306880977826, 'adjusted_hits_at_k': 0.26113281359609586}}

# %%
print("Training DistMult...")
result_distmult = pipeline(
    training=tf_train,
    validation=tf_valid,
    testing=tf_test,
    model="DistMult",
    model_kwargs=dict(embedding_dim=100),
    optimizer="Adam",
    optimizer_kwargs=dict(lr=0.001),
    training_kwargs=dict(num_epochs=100, batch_size=512),
    negative_sampler="basic",
    evaluator_kwargs=dict(filtered=True),
    random_seed=42,
)

# Extract metrics for both models
def get_metrics(result):
    r = result.metric_results.to_dict()["both"]["realistic"]
    return {
        "MRR":      round(r["inverse_harmonic_mean_rank"], 4),
        "Hits@1":   round(r["hits_at_1"], 4),
        "Hits@3":   round(r["hits_at_3"], 4),
        "Hits@10":  round(r["hits_at_10"], 4),
        "MeanRank": round(r["arithmetic_mean_rank"], 1),
    }

m_transe   = get_metrics(result_transe)
m_distmult = get_metrics(result_distmult)

print("\nModel Comparison (both head+tail, filtered, realistic)")
print(f"{'Metric':<12} {'TransE':>10} {'DistMult':>10}")
print("-" * 34)
for metric in ["MRR", "Hits@1", "Hits@3", "Hits@10", "MeanRank"]:
    print(f"{metric:<12} {m_transe[metric]:>10} {m_distmult[metric]:>10}")
# Out:
# WARNING:pykeen.utils:No cuda devices were available. The model runs on CPU
# INFO:pykeen.pipeline.api:Using device: None
# INFO:pykeen.nn.representation:Inferred unique=False for Embedding()
# INFO:pykeen.nn.representation:Inferred unique=False for Embedding(
#   (regularizer): LpRegularizer()
# )
# Training DistMult...
# Training epochs on cpu:   0%|          | 0/100 [00:00<?, ?epoch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/85.0 [00:00<?, ?batch/s]
# WARNING:pykeen.utils:Using automatic batch size on device.type='cpu' can cause unexplained out-of-memory crashes. Therefore, we use a conservative small batch_size=32. Performance may be improved by explicitly specifying a larger batch size.
# Evaluating on cpu:   0%|          | 0.00/905 [00:00<?, ?triple/s]
# WARNING:torch_max_mem.api:Encountered tensors on device_types={'cpu'} while only ['cuda'] are considered safe for automatic memory utilization maximization. This may lead to undocumented crashes (but can be safe, too).
# INFO:pykeen.evaluation.evaluator:Evaluation took 3.96s seconds
# Model Comparison (both head+tail, filtered, realistic)
# Metric           TransE   DistMult
# ----------------------------------
# MRR              0.1073     0.1314
# Hits@1           0.0227     0.0757
# Hits@3           0.1436     0.1508
# Hits@10          0.2613     0.2387
# MeanRank         2728.5     7212.6

# %%
# size sensitivity analysis
import numpy as np

def run_pipeline_on_subset(triples_list, size_label, model_name):
    """Train and evaluate a model on a subset of triples."""
    np.random.seed(42)
    subset = triples_list[:size_label]
    np.random.shuffle(subset)

    n = len(subset)
    n_train = int(0.8 * n)
    n_valid = int(0.1 * n)

    train_sub = subset[:n_train]
    valid_sub = subset[n_train:n_train + n_valid]
    test_sub  = subset[n_train + n_valid:]

    # Need at least a few triples in each split
    if len(train_sub) < 10 or len(valid_sub) < 2 or len(test_sub) < 2:
        return None

    tf_tr = TriplesFactory.from_labeled_triples(
        np.array(train_sub), create_inverse_triples=False
    )
    tf_va = TriplesFactory.from_labeled_triples(
        np.array(valid_sub),
        entity_to_id=tf_tr.entity_to_id,
        relation_to_id=tf_tr.relation_to_id,
        create_inverse_triples=False,
    )
    tf_te = TriplesFactory.from_labeled_triples(
        np.array(test_sub),
        entity_to_id=tf_tr.entity_to_id,
        relation_to_id=tf_tr.relation_to_id,
        create_inverse_triples=False,
    )

    result = pipeline(
        training=tf_tr,
        validation=tf_va,
        testing=tf_te,
        model=model_name,
        model_kwargs=dict(embedding_dim=100),
        optimizer="Adam",
        optimizer_kwargs=dict(lr=0.001),
        training_kwargs=dict(num_epochs=50, batch_size=256),
        negative_sampler="basic",
        evaluator_kwargs=dict(filtered=True),
        random_seed=42,
    )
    r = result.metric_results.to_dict()["both"]["realistic"]
    return {
        "MRR":     round(r["inverse_harmonic_mean_rank"], 4),
        "Hits@1":  round(r["hits_at_1"], 4),
        "Hits@10": round(r["hits_at_10"], 4),
    }

# Load all URI triples from expanded KB
from rdflib import Graph, URIRef
g_full = Graph()
g_full.parse(str(expanded_path), format="nt")

all_triples = [
    [str(s), str(p), str(o)]
    for s, p, o in g_full
    if isinstance(s, URIRef) and isinstance(p, URIRef) and isinstance(o, URIRef)
]
np.random.seed(42)
np.random.shuffle(all_triples)

print(f"Total URI triples available: {len(all_triples)}")

sizes = {"20k": 20000, "50k": 50000, "full": len(all_triples)}
sensitivity_results = {}

for label, size in sizes.items():
    subset = all_triples[:size]
    print(f"\nRunning TransE on {label} ({len(subset)} triples)...")
    metrics = run_pipeline_on_subset(subset, size, "TransE")
    sensitivity_results[label] = metrics
    if metrics:
        print(f"  MRR={metrics['MRR']}  Hits@1={metrics['Hits@1']}  Hits@10={metrics['Hits@10']}")

print("\nSize Sensitivity Analysis (TransE)")
print(f"{'Size':<8} {'MRR':>8} {'Hits@1':>8} {'Hits@10':>8}")
print("-" * 36)
for label, metrics in sensitivity_results.items():
    if metrics:
        print(f"{label:<8} {metrics['MRR']:>8} {metrics['Hits@1']:>8} {metrics['Hits@10']:>8}")
# Out:
# Total URI triples available: 54370
#
# Running TransE on 20k (20000 triples)...
# WARNING:pykeen.triples.triples_factory:You're trying to map triples with 1754 entities and 90 relations that are not in the training set. These triples will be excluded from the mapping.
# WARNING:pykeen.triples.triples_factory:In total 1756 from 2000 triples were filtered out
# WARNING:pykeen.triples.triples_factory:You're trying to map triples with 1736 entities and 91 relations that are not in the training set. These triples will be excluded from the mapping.
# WARNING:pykeen.triples.triples_factory:In total 1735 from 2000 triples were filtered out
# WARNING:pykeen.utils:No cuda devices were available. The model runs on CPU
# INFO:pykeen.pipeline.api:Using device: None
# INFO:pykeen.nn.representation:Inferred unique=False for Embedding()
# INFO:pykeen.nn.representation:Inferred unique=False for Embedding()
# Training epochs on cpu:   0%|          | 0/50 [00:00<?, ?epoch/s]
# Training batches on cpu:   0%|          | 0.00/63.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/63.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/63.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/63.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/63.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/63.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/63.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/63.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/63.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/63.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/63.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/63.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/63.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/63.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/63.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/63.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/63.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/63.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/63.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/63.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/63.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/63.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/63.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/63.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/63.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/63.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/63.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/63.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/63.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/63.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/63.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/63.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/63.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/63.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/63.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/63.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/63.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/63.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/63.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/63.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/63.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/63.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/63.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/63.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/63.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/63.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/63.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/63.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/63.0 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/63.0 [00:00<?, ?batch/s]
# WARNING:pykeen.utils:Using automatic batch size on device.type='cpu' can cause unexplained out-of-memory crashes. Therefore, we use a conservative small batch_size=32. Performance may be improved by explicitly specifying a larger batch size.
# Evaluating on cpu:   0%|          | 0.00/265 [00:00<?, ?triple/s]
# WARNING:torch_max_mem.api:Encountered tensors on device_types={'cpu'} while only ['cuda'] are considered safe for automatic memory utilization maximization. This may lead to undocumented crashes (but can be safe, too).
# INFO:pykeen.evaluation.evaluator:Evaluation took 1.58s seconds
#   MRR=0.0336  Hits@1=0.0075  Hits@10=0.0849
#
# Running TransE on 50k (50000 triples)...
# WARNING:pykeen.triples.triples_factory:You're trying to map triples with 4178 entities and 97 relations that are not in the training set. These triples will be excluded from the mapping.
# WARNING:pykeen.triples.triples_factory:In total 4179 from 5000 triples were filtered out
# WARNING:pykeen.triples.triples_factory:You're trying to map triples with 4224 entities and 99 relations that are not in the training set. These triples will be excluded from the mapping.
# WARNING:pykeen.triples.triples_factory:In total 4228 from 5000 triples were filtered out
# WARNING:pykeen.utils:No cuda devices were available. The model runs on CPU
# INFO:pykeen.pipeline.api:Using device: None
# INFO:pykeen.nn.representation:Inferred unique=False for Embedding()
# INFO:pykeen.nn.representation:Inferred unique=False for Embedding()
# Training epochs on cpu:   0%|          | 0/50 [00:00<?, ?epoch/s]
# Training batches on cpu:   0%|          | 0.00/157 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/157 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/157 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/157 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/157 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/157 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/157 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/157 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/157 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/157 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/157 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/157 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/157 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/157 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/157 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/157 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/157 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/157 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/157 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/157 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/157 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/157 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/157 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/157 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/157 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/157 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/157 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/157 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/157 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/157 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/157 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/157 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/157 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/157 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/157 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/157 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/157 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/157 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/157 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/157 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/157 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/157 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/157 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/157 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/157 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/157 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/157 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/157 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/157 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/157 [00:00<?, ?batch/s]
# WARNING:pykeen.utils:Using automatic batch size on device.type='cpu' can cause unexplained out-of-memory crashes. Therefore, we use a conservative small batch_size=32. Performance may be improved by explicitly specifying a larger batch size.
# Evaluating on cpu:   0%|          | 0.00/772 [00:00<?, ?triple/s]
# WARNING:torch_max_mem.api:Encountered tensors on device_types={'cpu'} while only ['cuda'] are considered safe for automatic memory utilization maximization. This may lead to undocumented crashes (but can be safe, too).
# INFO:pykeen.evaluation.evaluator:Evaluation took 9.54s seconds
#   MRR=0.0936  Hits@1=0.0227  Hits@10=0.2358
#
# Running TransE on full (54370 triples)...
# WARNING:pykeen.triples.triples_factory:You're trying to map triples with 4516 entities and 100 relations that are not in the training set. These triples will be excluded from the mapping.
# WARNING:pykeen.triples.triples_factory:In total 4517 from 5437 triples were filtered out
# WARNING:pykeen.triples.triples_factory:You're trying to map triples with 4579 entities and 108 relations that are not in the training set. These triples will be excluded from the mapping.
# WARNING:pykeen.triples.triples_factory:In total 4584 from 5437 triples were filtered out
# WARNING:pykeen.utils:No cuda devices were available. The model runs on CPU
# INFO:pykeen.pipeline.api:Using device: None
# INFO:pykeen.nn.representation:Inferred unique=False for Embedding()
# INFO:pykeen.nn.representation:Inferred unique=False for Embedding()
# Training epochs on cpu:   0%|          | 0/50 [00:00<?, ?epoch/s]
# Training batches on cpu:   0%|          | 0.00/170 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/170 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/170 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/170 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/170 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/170 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/170 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/170 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/170 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/170 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/170 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/170 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/170 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/170 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/170 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/170 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/170 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/170 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/170 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/170 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/170 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/170 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/170 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/170 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/170 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/170 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/170 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/170 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/170 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/170 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/170 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/170 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/170 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/170 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/170 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/170 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/170 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/170 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/170 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/170 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/170 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/170 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/170 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/170 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/170 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/170 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/170 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/170 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/170 [00:00<?, ?batch/s]
# Training batches on cpu:   0%|          | 0.00/170 [00:00<?, ?batch/s]
# WARNING:pykeen.utils:Using automatic batch size on device.type='cpu' can cause unexplained out-of-memory crashes. Therefore, we use a conservative small batch_size=32. Performance may be improved by explicitly specifying a larger batch size.
# Evaluating on cpu:   0%|          | 0.00/853 [00:00<?, ?triple/s]
# WARNING:torch_max_mem.api:Encountered tensors on device_types={'cpu'} while only ['cuda'] are considered safe for automatic memory utilization maximization. This may lead to undocumented crashes (but can be safe, too).
# INFO:pykeen.evaluation.evaluator:Evaluation took 11.11s seconds
#   MRR=0.1084  Hits@1=0.0182  Hits@10=0.2556
#
# Size Sensitivity Analysis (TransE)
# Size          MRR   Hits@1  Hits@10
# ------------------------------------
# 20k        0.0336   0.0075   0.0849
# 50k        0.0936   0.0227   0.2358
# full       0.1084   0.0182   0.2556

# %%
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# retrieve entity embeddings from trained model
entity_embeddings = result_transe.model.entity_representations[0](indices=None).detach().cpu().numpy()
entity_labels = list(tf_train.entity_to_id.keys())

print(f"Embedding matrix shape: {entity_embeddings.shape}")

# run t-SNE on a sample of 500 entities for readability
np.random.seed(42)
sample_idx = np.random.choice(len(entity_labels), size=min(500, len(entity_labels)), replace=False)
sample_embeddings = entity_embeddings[sample_idx]
sample_labels = [entity_labels[i] for i in sample_idx]

tsne = TSNE(n_components=2, random_state=42, perplexity=30, n_iter=1000)
coords = tsne.fit_transform(sample_embeddings)

# plot
fig, ax = plt.subplots(figsize=(12, 8))
ax.scatter(coords[:, 0], coords[:, 1], s=8, alpha=0.6, color='steelblue')

# annotate a few known climate entities
known = {
    "http://www.wikidata.org/entity/Q42262": "IPCC",
    "http://www.wikidata.org/entity/Q1065": "UN",
    "http://www.wikidata.org/entity/Q23548": "NASA",
    "http://www.wikidata.org/entity/Q167639": "Paris Agreement",
    "http://www.wikidata.org/entity/Q19673": "Al Gore",
    "http://www.wikidata.org/entity/Q30": "United States",
    "http://www.wikidata.org/entity/Q170322": "UNFCCC",
}

for j, label in enumerate(sample_labels):
    if label in known:
        ax.annotate(known[label], (coords[j, 0], coords[j, 1]),
                    fontsize=9, fontweight='bold',
                    xytext=(5, 5), textcoords='offset points',
                    arrowprops=dict(arrowstyle='->', color='black', lw=0.8))
        ax.scatter(coords[j, 0], coords[j, 1], s=40, color='crimson', zorder=5)

ax.set_title("t-SNE Projection of TransE Entity Embeddings (500 entities)", fontsize=13)
ax.set_xlabel("Dimension 1")
ax.set_ylabel("Dimension 2")
ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.savefig("tsne_embeddings.png", dpi=150, bbox_inches='tight')
plt.show()
print("tsne_embeddings.png saved.")
# Out:
# Embedding matrix shape: (38265, 100)
# tsne_embeddings.png saved.

# %%
fig, ax = plt.subplots(figsize=(12, 8))
ax.scatter(coords[:, 0], coords[:, 1], s=8, alpha=0.6, color='steelblue')

# force annotation of all known entities found in sample
found_any = False
for j, label in enumerate(sample_labels):
    if label in known:
        found_any = True
        ax.annotate(known[label], (coords[j, 0], coords[j, 1]),
                    fontsize=9, fontweight='bold',
                    xytext=(8, 8), textcoords='offset points',
                    arrowprops=dict(arrowstyle='->', color='black', lw=0.8))
        ax.scatter(coords[j, 0], coords[j, 1], s=60, color='crimson', zorder=5)

if not found_any:
    print("No known entities in sample — adding them manually")
    for uri, name in known.items():
        if uri in tf_train.entity_to_id:
            idx = tf_train.entity_to_id[uri]
            vec = entity_embeddings[idx:idx+1]
            coord = TSNE(n_components=2, random_state=42, perplexity=5).fit_transform(
                np.vstack([sample_embeddings[:50], vec])
            )[-1]
            ax.scatter(coord[0], coord[1], s=60, color='crimson', zorder=5)
            ax.annotate(name, (coord[0], coord[1]), fontsize=9, fontweight='bold',
                        xytext=(8,8), textcoords='offset points')

ax.set_title("t-SNE Projection of TransE Entity Embeddings (500 entities)", fontsize=13)
ax.set_xlabel("Dimension 1")
ax.set_ylabel("Dimension 2")
ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.savefig("tsne_embeddings.png", dpi=150, bbox_inches='tight')
plt.show()
print("saved.")
# Out:
# No known entities in sample — adding them manually
# saved.
